# %% [markdown]
# # Class Goals
# - get a **good grade**
# - learn how to use python
# - understand real world applications of technology

# %% [markdown]
# # Things I learned the first day
# 1. My computer doesn't like *cooperating*
# 2. How to open jupyter notebook
# 3. the definition of a markdown cell
# ## Other thoughts about the first day
# - this is the largest class I've had in grad school
# - I am *less* worried successful than when I started

# %% [markdown]
# ![SystemsCheck_Image.png](attachment:b7f9a07a-51a5-4d54-9aac-6617ad4016da.png)

# %%
z = 4

# %%
z
# Out:
# 4

# %%
school = [ 'pencil', 'shoe', 'notebook', 'eraser' ]

# %%
for supplies in school:
    print(supplies)
# Out:
# pencil
# shoe
# notebook
# eraser

# %%
school_supplies = 'Need'

# %%
def display_supplies(z): 
    print(z)

# %%
display_supplies(school_supplies)
# Out:
# Need

# %%
def change_supplies(z):
    more_supplies = z + 'more'
    return more_supplies

# %%
changed_supplies = change_supplies('Need')
changed_supplies
# Out:
# 'Needmore'
